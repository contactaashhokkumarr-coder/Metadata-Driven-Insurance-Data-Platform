# %%
# ==========================================
# Unity Catalog Configuration
# ==========================================

catalog_name = "dbw_insurance"

bronze_schema = "insurance_bronze"
silver_schema = "insurance_silver"
gold_schema = "insurance_gold"
metadata_schema = "insurance_metadata"
audit_schema = "insurance_audit"

# %%
# ==========================================
# Insurance Project Configuration
# ==========================================

storage_account_name = "adlsinsurancedevstorage"
storage_account_key = "yxKNKOmuBC7KRANbECJ5l/kF12v7vp0hgy5K2f60eYbqc0pxBqXF66mZHyaNjo45jer7R7zdnR+0+AStzgxWAw=="

spark.conf.set(
    f"fs.azure.account.key.{storage_account_name}.dfs.core.windows.net",
    storage_account_key)

landing_path = f"abfss://landing@{storage_account_name}.dfs.core.windows.net/"
bronze_path  = f"abfss://bronze@{storage_account_name}.dfs.core.windows.net/"
silver_path  = f"abfss://silver@{storage_account_name}.dfs.core.windows.net/"
gold_path    = f"abfss://gold@{storage_account_name}.dfs.core.windows.net/"

print("Configuration Loaded Successfully")
# Out:
# Configuration Loaded Successfully

# %%
# # Check schema of bronze_config table
# print("=== BRONZE CONFIG SCHEMA ===")
# spark.read.table("insurance_metadata.bronze_config").printSchema()

# print("\n=== BRONZE CONFIG SAMPLE DATA ===")
# display(spark.read.table("insurance_metadata.bronze_config"))

# # Check schema of watermark_table
# print("\n=== WATERMARK TABLE SCHEMA ===")
# spark.read.table("insurance_metadata.watermark_table").printSchema()

# print("\n=== WATERMARK TABLE SAMPLE DATA ===")
# display(spark.read.table("insurance_metadata.watermark_table"))
# Out:
# === BRONZE CONFIG SCHEMA ===
# root
#  |-- table_name: string (nullable = true)
#  |-- source_folder: string (nullable = true)
#  |-- target_table: string (nullable = true)
#  |-- gold_table: string (nullable = true)
#  |-- history_table: string (nullable = true)
#  |-- file_format: string (nullable = true)
#  |-- load_strategy: string (nullable = true)
#  |-- primary_key: string (nullable = true)
#  |-- source_system: string (nullable = true)
#  |-- watermark_column: string (nullable = true)
#  |-- compare_columns: string (nullable = true)
#  |-- scd_enabled: string (nullable = true)
#  |-- active: string (nullable = true)
#
#
# === BRONZE CONFIG SAMPLE DATA ===
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
