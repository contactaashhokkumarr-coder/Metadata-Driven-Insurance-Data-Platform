# %% [markdown]
# **insurance_metadata schema (2 tables)**

# %%
# %sql
SHOW CREATE TABLE dbw_insurance.insurance_metadata.bronze_config;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>createtab_stmt</th></tr></thead><tbody><tr><td>CREATE TABLE dbw_insurance.insurance_metadata.bronze_config (
#   table_name STRING,
#   source_folder STRING,
#   target_table STRING,
#   gold_table STRING,
#   history_table STRING,
#   file_format STRING,
#   load_strategy STRING,
#   primary_key STRING,
#   source_system STRING,
#   watermark_column STRING,
#   compare_columns STRING,
#   scd_enabled STRING,
#   active STRING)
# USING delta
# COMMENT 'The table contains configuration details for data processing related to insurance datasets. Each entry includes information about the source folder, target table, and associated metadata such as file format and load strategy. This data can be utilized for understanding data flows, managing data pipelines, and monitoring the status of various historical and active tables.'
# TBLPROPERTIES (
#   'delta.enableDeletionVectors' = 'true',
#   'delta.enableRowTracking' = 'true',
#   'delta.feature.appendOnly' = 'supported',
#   'delta.feature.deletionVectors' = 'supported',
#   'delta.feature.domainMetadata' = 'supported',
#   'delta.feature.invariants' = 'supported',
#   'delta.feature.rowTracking' = 'supported',
#   'delta.minReaderVersion' = '3',
#   'delta.minWriterVersion' = '7',
#   'delta.parquet.compression.codec' = 'zstd')
# </td></tr></tbody></table></div>

# %%
# %sql
SHOW CREATE TABLE dbw_insurance.insurance_metadata.pipeline_watermark;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>createtab_stmt</th></tr></thead><tbody><tr><td>CREATE TABLE dbw_insurance.insurance_metadata.pipeline_watermark (
#   table_name STRING,
#   last_watermark TIMESTAMP)
# USING delta
# TBLPROPERTIES (
#   'delta.enableDeletionVectors' = 'true',
#   'delta.enableRowTracking' = 'true',
#   'delta.feature.appendOnly' = 'supported',
#   'delta.feature.deletionVectors' = 'supported',
#   'delta.feature.domainMetadata' = 'supported',
#   'delta.feature.invariants' = 'supported',
#   'delta.feature.rowTracking' = 'supported',
#   'delta.minReaderVersion' = '3',
#   'delta.minWriterVersion' = '7',
#   'delta.parquet.compression.codec' = 'zstd')
# </td></tr></tbody></table></div>

# %% [markdown]
# **insurance_audit schema**

# %%
# %sql
SELECT *
FROM dbw_insurance.insurance_audit.pipeline_audit
ORDER BY end_time DESC LIMIT 20 ;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>pipeline_name</th><th>table_name</th><th>load_type</th><th>start_time</th><th>end_time</th><th>rows_read</th><th>rows_written</th><th>status</th><th>error_message</th><th>pipeline_run_id</th></tr></thead><tbody><tr><td>Enterprise_Generic_SCD2_Loader_v4</td><td>dim_customer_history</td><td>SCD2</td><td>2026-07-31T15:28:59.002127Z</td><td>2026-07-31T15:28:59.002127Z</td><td>925</td><td>0</td><td>SUCCESS</td><td></td><td>c15d3a57-711b-4bb9-8182-28956850d9ea</td></tr><tr><td>Enterprise_Generic_SCD2_Loader_v4</td><td>dim_branch_history</td><td>SCD2</td><td>2026-07-31T15:28:52.673
_Loader_v4</td><td>claim</td><td>INCREMENTAL</td><td>2026-07-31T15:26:30.428628Z</td><td>2026-07-31T15:26:30.428628Z</td><td>943</td><td>943</td><td>SUCCESS</td><td></td><td>c15d3a57-711b-4bb9-8182-28956850d9ea</td></tr><tr><td>Enterprise_Generic_Silver_Loader_v4</td><td>branch</td><td>FULL</td><td>2026-07-31T15:26:23.764939Z</td><td>2026-07-31T15:26:23.764939Z</td><td>1000</td><td>1000</td><td>SUCCESS</td><td></td><td>c15d3a57-711b-4bb9-8182-28956850d9ea</td></tr><tr><td>Enterprise_Generic_Silver_Loader_v4</td><td>agent</td><td>FULL</td><td>2026-07-31T15:26:16.56423Z</td><td>2026-07-31T15:26:16.56423Z</td><td>2005</td><td>1005</td><td>SUCCESS</td><td></td><td>c15d3a57-711b-4bb9-8182-28956850d9ea</td></tr><tr><td>Enterprise_Generic_Bronze_Loader_v4</td><td>policy</td><td>FULL</td><td>2026-07-31T15:25:27.708633Z</td><td>2026-07-31T15:25:27.708633Z</td><td>1000</td><td>1000</td><td>SUCCESS</td><td></td><td>c15d3a57-711b-4bb9-8182-28956850d ...

# %% [markdown]
# **insurance_bronze schema (5 tables)**

# %%
# %sql
SHOW CREATE TABLE dbw_insurance.insurance_bronze.agent;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>createtab_stmt</th></tr></thead><tbody><tr><td>CREATE TABLE dbw_insurance.insurance_bronze.agent (
#   agent_id INT,
#   agent_name STRING,
#   agent_email STRING,
#   agent_phone BIGINT,
#   branch_id INT,
#   create_timestamp STRING,
#   ingestion_timestamp TIMESTAMP,
#   source_file_name STRING,
#   pipeline_run_id STRING,
#   load_id STRING,
#   source_system STRING)
# USING delta
# TBLPROPERTIES (
#   'delta.enableDeletionVectors' = 'true',
#   'delta.feature.appendOnly' = 'supported',
#   'delta.feature.deletionVectors' = 'supported',
#   'delta.feature.invariants' = 'supported',
#   'delta.minReaderVersion' = '3',
#   'delta.minWriterVersion' = '7',
#   'delta.parquet.compression.codec' = 'zstd')
# </td></tr></tbody></table></div>

# %%
# %sql
SHOW CREATE TABLE dbw_insurance.insurance_bronze.branch;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>createtab_stmt</th></tr></thead><tbody><tr><td>CREATE TABLE dbw_insurance.insurance_bronze.branch (
#   branch_id INT,
#   branch_country STRING,
#   branch_city STRING,
#   LastUpdatedTimeStamp TIMESTAMP,
#   ingestion_timestamp TIMESTAMP,
#   source_file_name STRING,
#   pipeline_run_id STRING,
#   load_id STRING,
#   source_system STRING)
# USING delta
# TBLPROPERTIES (
#   'delta.enableDeletionVectors' = 'true',
#   'delta.feature.appendOnly' = 'supported',
#   'delta.feature.deletionVectors' = 'supported',
#   'delta.feature.invariants' = 'supported',
#   'delta.minReaderVersion' = '3',
#   'delta.minWriterVersion' = '7',
#   'delta.parquet.compression.codec' = 'zstd')
# </td></tr></tbody></table></div>

# %%
# %sql
SHOW CREATE TABLE dbw_insurance.insurance_bronze.claim;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>createtab_stmt</th></tr></thead><tbody><tr><td>CREATE TABLE dbw_insurance.insurance_bronze.claim (
#   claim_id INT,
#   policy_id INT,
#   date_of_claim TIMESTAMP,
#   claim_amount DOUBLE,
#   claim_status STRING,
#   LastUpdatedTimeStamp TIMESTAMP,
#   ingestion_timestamp TIMESTAMP,
#   source_file_name STRING,
#   pipeline_run_id STRING,
#   load_id STRING,
#   source_system STRING)
# USING delta
# TBLPROPERTIES (
#   'delta.enableDeletionVectors' = 'true',
#   'delta.feature.appendOnly' = 'supported',
#   'delta.feature.deletionVectors' = 'supported',
#   'delta.feature.invariants' = 'supported',
#   'delta.minReaderVersion' = '3',
#   'delta.minWriterVersion' = '7',
#   'delta.parquet.compression.codec' = 'zstd')
# </td></tr></tbody></table></div>

# %%
# %sql
SHOW CREATE TABLE dbw_insurance.insurance_bronze.customer;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>createtab_stmt</th></tr></thead><tbody><tr><td>CREATE TABLE dbw_insurance.insurance_bronze.customer (
#   customer_id INT,
#   first_name STRING,
#   last_name STRING,
#   email STRING,
#   phone BIGINT,
#   country STRING,
#   city STRING,
#   registration_date TIMESTAMP,
#   date_of_birth TIMESTAMP,
#   gender STRING,
#   ingestion_timestamp TIMESTAMP,
#   source_file_name STRING,
#   load_id STRING,
#   pipeline_run_id STRING,
#   source_system STRING,
#   _ingestion_timestamp TIMESTAMP,
#   _source_file_name STRING,
#   _pipeline_run_id STRING)
# USING delta
# TBLPROPERTIES (
#   'delta.enableDeletionVectors' = 'true',
#   'delta.feature.appendOnly' = 'supported',
#   'delta.feature.deletionVectors' = 'supported',
#   'delta.feature.invariants' = 'supported',
#   'delta.minReaderVersion' = '3',
#   'delta.minWriterVersion' = '7',
#   'delta.parquet.compression.codec' = 'zstd')
# </td></tr></tbody></table></div>

# %%
# %sql
SHOW CREATE TABLE dbw_insurance.insurance_bronze.policy;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>createtab_stmt</th></tr></thead><tbody><tr><td>CREATE TABLE dbw_insurance.insurance_bronze.policy (
#   _corrupt_record STRING,
#   coverage_amount BIGINT,
#   customer_id BIGINT,
#   end_date STRING,
#   policy_id BIGINT,
#   policy_type STRING,
#   premium BIGINT,
#   start_date STRING,
#   ingestion_timestamp TIMESTAMP,
#   source_file_name STRING,
#   pipeline_run_id STRING,
#   load_id STRING,
#   source_system STRING)
# USING delta
# TBLPROPERTIES (
#   'delta.enableDeletionVectors' = 'true',
#   'delta.feature.appendOnly' = 'supported',
#   'delta.feature.deletionVectors' = 'supported',
#   'delta.feature.invariants' = 'supported',
#   'delta.minReaderVersion' = '3',
#   'delta.minWriterVersion' = '7',
#   'delta.parquet.compression.codec' = 'zstd')
# </td></tr></tbody></table></div>
